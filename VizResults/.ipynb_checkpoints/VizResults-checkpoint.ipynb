# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import networkx as nx

import matplotlib.pyplot as plt

from helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load

# %%
Folder_results='../pb2/'
Folder_params='/home/lucasfv/Documents/AMOD/amod_fw/data/elastic_Pb2/exp/1_0/'

# %%
flow=pd.read_csv(Folder_results+'flow.csv',header=1)

edges=pd.read_csv(Folder_params+'edges.csv')

# %%
nIter=flow['numIteration'].max()

flow_last=flow[flow['numIteration']==nIter]

# %%
pos=get_nodes_pos()

# %% [markdown]
# # Build Graph

# %%
G=transform_output_to_graph(flow_last)

# %%
plt.figure(figsize=(18,10))
nx.draw_networkx_nodes(G,pos);
nx.draw_networkx_labels(G,pos);
nx.draw_networkx_edges(G,pos);
nx.draw_networkx_edge_labels(G,pos);

# %% [markdown]
# It looks like there is some impossibility here to balance the flows...?

# %% [markdown]
# Why is that the case?

# %%
check_flow_balance(G)
# Out:
# {0: 8.559999999999999,
#  1: 11.440000000000001,
#  2: 10.0,
#  3: 0.0,
#  4: 0.0,
#  5: 0.0,
#  6: -4.440892098500626e-16,
#  7: -10.0,
#  8: -10.0,
#  9: 10.0,
#  10: 0.0,
#  11: 0.0,
#  12: -0.010000000000000675,
#  13: 0.009999999999999787,
#  14: -10.0,
#  15: -10.0}

# %%
#What are the different paths? 

#0-1
path_0_1=[[0,1,5,6,7],[0,3,4,7]]

#0_1_rebalancers
path_0_1_r=[[2,3,4,1,0,8],[2,5,6,8],[2,6,8],[2,3,4,1,10,11,0,8]]

# %%
costs_0_1=cost_path(flow_last,path_0_1)
print(costs_0_1)

costs_0_1_r=cost_path(flow_last,path_0_1_r)
print(costs_0_1_r)
# Out:
# [18688.648, 18690.1]
# [18726.5069, 18723.1051, 18725.2051, 36969.3]

# %%
#Sanity checks for control edges
#control 1 
edge_c_1=[[3,4],[5,6]]
print "Cost of control edges for first part of graph: ",cost_path(flow_last,edge_c_1)
print "Flows: ", flow_on_edges(flow_last,edge_c_1)


#control 2
edge_c_2=[[10,11],[12,13]]
print "Cost of control edges for second part of the graph: ",cost_path(flow_last,edge_c_2)
print "Flows: ", flow_on_edges(flow_last,edge_c_2)
# Out:
# Cost of control edges for first part of graph:  [18690.1, 18596.7]
# Flows:  [7.11033, 7.10151]
# Cost of control edges for second part of the graph:  [18279.2, 18225.1]
# Flows:  [5.670730000000001, 5.844930000000001]

# %% [markdown]
# # Files Viz

# %%
flow.head()
# Out:
#    numIteration  tail  head  freeFlowCost  actualCost  capacity  flow
# 0             1     0     1            36        41.4        10  10.0
# 1             1     0     3             0         0.0        10   0.0
# 2             1     0     8             0         0.0        10   0.0
# 3             1     0    12             4        84.2         3  10.0
# 4             1     1     0            36        41.4        10  10.0

# %%
edges.head()
# Out:
#    edge_tail  edge_head  length  capacity  speed
# 0          0          1      10        10     10
# 1          1          0      10        10     10
# 2          0          3       0        10     10
# 3          1          5       1         1     10
# 4          2          3       0        10     10

# %%
flow_last.head()
# Out:
#       numIteration  tail  head  freeFlowCost  actualCost  capacity     flow
# 5174           200     0     1            36     36.1126        10  3.79966
# 5175           200     0     3             0      0.0000        10  7.11033
# 5176           200     0     8             0      0.0000        10  0.00000
# 5177           200     0    12             4     19.5814         3  5.23926
# 5178           200     1     0            36     36.4069        10  5.23926
